# %%
import splitfolders
from keras.preprocessing.image import ImageDataGenerator
import cv2
import numpy as np
import pandas as pd
import os
import string
from sklearn.utils import shuffle
import splitfolders

# %%
class CONFIG:
    SRC_DATA_PATH = '../DATA'
    OUT_DATA_PATH = '../DATA_TRAIN_TEST'
    
    TRAIN_DATA_PATH = '../DATA_TRAIN_TEST/train'
    TEST_DATA_PATH = '../DATA_TRAIN_TEST/val'
    
    SEED = 2

# %% [markdown]
# # Split Train Test Data

# %%
# splitfolders.ratio(CONFIG.SRC_DATA_PATH, output=CONFIG.OUT_DATA_PATH, seed=CONFIG.SEED, ratio=(0.8, 0.2))

# %% [markdown]
# # Convert Data to Mnist Format

# %%
def resize_128_x_128(label, img, df):
    _img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
    img_resize = cv2.resize(_img, (128,128))
    
    img_resize_ravel = img_resize.ravel()
    
    data_concate = np.concatenate([[label], img_resize_ravel])
    
    df.loc[len(df.index)] = data_concate

# %% [markdown]
# ## Training Data

# %%
pixel_columns = ['label'] + [f'pixels_{i+1}' for i in range(16384)] 
df_train = pd.DataFrame(columns=pixel_columns)

# %%
for path in os.listdir(CONFIG.TRAIN_DATA_PATH):
    for img in os.listdir(CONFIG.TRAIN_DATA_PATH + f'/{path}'):
        img_path = CONFIG.TRAIN_DATA_PATH + f'/{path}' + f'/{img}'
        resize_img = resize_128_x_128(label=int(path), img=img_path, df=df_train)
        
    print(f'{path} selesai')
# Out:
# 1 selesai
# 10 selesai
# 11 selesai
# 12 selesai
# 13 selesai
# 14 selesai
# 15 selesai
# 16 selesai
# 17 selesai
# 18 selesai
# 19 selesai
# 2 selesai
# 20 selesai
# 21 selesai
# 22 selesai
# 23 selesai
# 24 selesai
# 25 selesai
# 26 selesai
# 3 selesai
# 4 selesai
# 5 selesai
# 6 selesai
# 7 selesai
# 8 selesai
# 9 selesai

# %%
df_train.head()
# Out:
#    label  pixels_1  pixels_2  pixels_3  pixels_4  pixels_5  pixels_6  \
# 0      1       254       253       255       255       255       255
# 1      1       254       106       106       105       105       105
# 2      1       254       106       106       105       105       105
# 3      1       254       106       106       105       105       105
# 4      1       153       107       105       105       105       105
#
#    pixels_7  pixels_8  pixels_9  ...  pixels_16375  pixels_16376  \
# 0       255       255       255  ...           255           255
# 1       105       105       105  ...           138           138
# 2       105       105       105  ...           138           138
# 3       105       105       105  ...           138           138
# 4       105       105       105  ...           138           138
#
#    pixels_16377  pixels_16378  pixels_16379  pixels_16380  pixels_16381  \
# 0           255           255           255           255           255
# 1           138           138           138           138           139
# 2           138           138           138           138           139
# 3           138           138           138           138           139
# 4           138           138           138           138           138
#
#    pixels_16382  pixels_16383  pixels_16384
# 0           255           255           255
# 1           139           105           255
# 2           139           105           255
# 3           139           105           255
# 4           138           136           154
#
# [5 rows x 16385 columns]

# %%
df_train.to_csv('../DATA_TRAIN_TEST/train/train.csv')

# %% [markdown]
# ## Testing Data

# %%
pixel_columns = ['label'] + [f'pixels_{i+1}' for i in range(16384)] 
df_test = pd.DataFrame(columns=pixel_columns)

# %%
for path in os.listdir(CONFIG.TEST_DATA_PATH):
    for img in os.listdir(CONFIG.TEST_DATA_PATH + f'/{path}'):
        img_path = CONFIG.TEST_DATA_PATH + f'/{path}' + f'/{img}'
        resize_img = resize_128_x_128(label=int(path), img=img_path, df=df_test)
        
    print(f'{path} selesai')

# %%
df_test.head()
# Out:
#   label pixels_1 pixels_2 pixels_3 pixels_4 pixels_5 pixels_6 pixels_7  \
# 0     1      255      255      255      255      255      212      105
# 1     1      255      255      255      255      255      212      105
# 2     1      255      255      255      255      255      255      104
# 3     1      255      255      255      255      255      255      255
# 4     1      255      255      255      255      255      212      105
#
#   pixels_8 pixels_9  ... pixels_4087 pixels_4088 pixels_4089 pixels_4090  \
# 0      105      105  ...         141         138         134         126
# 1      105      105  ...         141         143         138         141
# 2      106      105  ...         135         146         148         134
# 3      104      105  ...          67          67          85         255
# 4      105      105  ...          62          84          94          93
#
#   pixels_4091 pixels_4092 pixels_4093 pixels_4094 pixels_4095 pixels_4096
# 0         106         255         255         255         255         255
# 1         107         255         255         255         255         255
# 2         255         255         255         255         255         255
# 3         255         255         255         255         255         255
# 4         213         255         255         255         255         255
#
# [5 rows x 4097 columns]

# %%
df_test.to_csv(shuffle(CONFIG.TEST_DATA_PATH + '/test.csv'), index=False)
